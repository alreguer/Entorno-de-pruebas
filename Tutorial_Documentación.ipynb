# %% [markdown]
# <a href="https://colab.research.google.com/github/alreguer/Entorno-de-pruebas/blob/main/Tutorial_Documentaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
base=5
altura=7
area = base * altura
print("El área es: "+ str(area))
print(f"El área es: {area}") # Otra forma de imprimir por pantalla los resultados
# Out:
# El área es: 35
# El área es: 35

# %%
# FECHA:
# AUTOR: profesores de Informática
# DESCRIPCIÓN:
# Calcula el valor de un polinomio de tercer grado para un valor concreto de la incógnita
# x. Los coeficientes del polinomio son introducidos por teclado, así como el valor de la
# incógnita. El resultado se presenta por pantalla.
# ENTRADAS: los coeficientes del polinomio (variables a,b,c,d)
# el valor de la incógnita (variable x)
# SALIDAS: el resultado de la expresión ax^3+bx^2+cx+d (almacenado en la variable p)

# Entrada de datos
print("Introducir los valores de:")
print("a = ?")
a=int(input())
print("b = ?")
b=int(input())
print("c = ?")
c=int(input())
print("d = ?")
d=int(input())
print("x = ?")
x=int(input())
# Proceso
p = a*x*x*x + b*x*x + c*x + d;
# Salida
print("La solución es p = ", p);
# Out:
# Introducir los valores de:
# a = ?
# 5
# b = ?
# 2
# c = ?
# 10
# d = ?
# 4
# x = ?
# 14
# La solución es p =  14256

# %%
"""
FECHA:
AUTOR: profesores de Informática
DESCRIPCIÓN:
Calcula el número de apariciones de una subcadena dentro de una cadena que se
pase por teclado.
Si no hay apariciones de la subcadena el programa devolverá 0.
ENTRADAS: la cadena principal sobre la que realizaremos la búsqueda y la cadena
que se quiere buscar
SALIDAS: el número de apariciones de la subcadena
ERRORES:

"""

contador = 0 #Inicializamos un contador a 0 para llevar la cuenta de las ocurrencias

# Pedimos al usuario que ingrese las cadenas
cadena = input("Ingrese la cadena principal: ")
subcadena = input("Ingrese la subcadena a buscar: ")

contador = cadena.count(subcadena) #la función count se ejecuta sobre cadena y
#cuenta el número de veces que aparece subcadenak

# Mostramos el resultado
print("La subcadena aparece", contador, "veces.")
# Out:
# Ingrese la cadena principal: esto es una prueba
# Ingrese la subcadena a buscar: lo
# La subcadena aparece 0 veces.
